-14</td><td>C3598</td><td>Robert Rodriguez</td><td>P5980</td><td>Monitor</td><td>Electronics</td><td>Computers</td><td>7</td><td>348.93</td><td>2442.51</td><td>South</td></tr><tr><td>56</td><td>2024-11-13</td><td>C3742</td><td>Debra Nguyen</td><td>P2507</td><td>Headphones</td><td>Accessories</td><td>Storage Devices</td><td>4</td><td>978.77</td><td>3915.08</td><td>South</td></tr><tr><td>61</td><td>2024-07-06</td><td>C7014</td><td>Joanne Mcclain</td><td>P5772</td><td>Headphones</td><td>Accessories</td><td>Storage Devices</td><td>9</td><td>58.6</td><td>527.4</td><td>South</td></tr><tr><td>68</td><td>2024-10-01</td><td>C8138</td><td>Gabrielle Krause</td><td>P2133</td><td>Laptop</td><td>Electronics</td><td>Peripherals</td><td>8</td><td>731.48</td><td>5851.84</td><td>South</td></tr><tr><td>70</td><td>2024-12-26</td><td>C6273</td><td>Christopher Jimenez</td><td>P3200</td><td>Unknown</td><td>Accessories</td><td>Storage Devices</td><td>7</td><td>751.52</td><td>5260.64</td><td>South</td></tr><tr><td>71</td><td>2024-10-07</td><t ...
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ## Sales over the period of year where we can see a decline in sales which tells the need of investigation in customer behaviour and trends

# %%
# %sql
SELECT 
  DATE_TRUNC('month', OrderDate) AS month,
  SUM(TotalAmount) AS total_sales
FROM silver.sales_2k
GROUP BY 1
ORDER BY 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>total_sales</th></tr></thead><tbody><tr><td>2024-06-01T00:00:00.000Z</td><td>2975035.3899999973</td></tr><tr><td>2024-07-01T00:00:00.000Z</td><td>4719052.829999999</td></tr><tr><td>2024-08-01T00:00:00.000Z</td><td>4622362.570000004</td></tr><tr><td>2024-09-01T00:00:00.000Z</td><td>4682603.240000001</td></tr><tr><td>2024-10-01T00:00:00.000Z</td><td>4801087.530000003</td></tr><tr><td>2024-11-01T00:00:00.000Z</td><td>4621143.399999996</td></tr><tr><td>2024-12-01T00:00:00.000Z</td><td>4885781.960000011</td></tr><tr><td>2025-01-01T00:00:00.000Z</td><td>4593673.190000002</td></tr><tr><td>2025-02-01T00:00:00.000Z</td><td>4193491.570000003</td></tr><tr><td>2025-03-01T00:00:00.000Z</td><td>4739078.989999994</td></tr><tr><td>2025-04-01T00:00:00.000Z</td><td>4684102.019999998</td></tr><tr><td>2025-05-01T00:00:00.000Z</td><td>4815200.029999999</td></tr><tr><td>2025-06-01T00:00:00.000Z</td><td>1662193.8699999996</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ## Knowing the top selling products

# %%
# %sql
select ProductName , 
SUM(TotalAmount) as total_sales
from silver.sales_2k
group by ProductName
order by total_sales desc
limit 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ProductName</th><th>total_sales</th></tr></thead><tbody><tr><td>Headphones</td><td>4879957.299999997</td></tr><tr><td>Bookshelf</td><td>4723274.889999993</td></tr><tr><td>Desk</td><td>4596539.670000001</td></tr><tr><td>Office Chair</td><td>4591802.759999999</td></tr><tr><td>Table Lamp</td><td>4561252.570000003</td></tr><tr><td>Keyboard</td><td>4538122.489999999</td></tr><tr><td>USB Drive</td><td>4536790.12</td></tr><tr><td>Mouse</td><td>4454574.329999993</td></tr><tr><td>Monitor</td><td>3844119.120000001</td></tr><tr><td>Webcam</td><td>3787194.0100000016</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ## Sales by category  and sub-category

# %%
# %sql
SELECT 
  Category,
  SubCategory,
  SUM(TotalAmount) AS total_sales
FROM silver.sales_2k
WHERE SubCategory != 'Unknown' AND TotalAmount > 2000
GROUP BY Category, SubCategory
ORDER BY SUM(TotalAmount) DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Category</th><th>SubCategory</th><th>total_sales</th></tr></thead><tbody><tr><td>Accessories</td><td>Input Devices</td><td>5419969.879999995</td></tr><tr><td>Electronics</td><td>Peripherals</td><td>5385899.920000007</td></tr><tr><td>Furniture</td><td>Storage</td><td>5245206.7900000075</td></tr><tr><td>Furniture</td><td>Seating</td><td>5229691.420000002</td></tr><tr><td>Electronics</td><td>Computers</td><td>5214331.880000006</td></tr><tr><td>Accessories</td><td>Storage Devices</td><td>5094123.619999996</td></tr><tr><td>Furniture</td><td>Tables</td><td>5078722.559999994</td></tr><tr><td>Electronics</td><td>Mobile Devices</td><td>4957146.92</td></tr><tr><td>Accessories</td><td>Audio</td><td>4888878.420000003</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ## Regional Sales Distribution

# %%
# %sql
SELECT 
  region,
  SUM(TotalAmount) AS total_sales
FROM silver.sales_2k
GROUP BY region
ORDER BY total_sales DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region</th><th>total_sales</th></tr></thead><tbody><tr><td>East</td><td>1.431392694999999E7</td></tr><tr><td>South</td><td>1.403189657000001E7</td></tr><tr><td>West</td><td>1.3953700170000015E7</td></tr><tr><td>North</td><td>1.3695282900000053E7</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
describe gold.sales_monthly
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>month_key</td><td>string</td><td>null</td></tr><tr><td>Region</td><td>string</td><td>null</td></tr><tr><td>Category</td><td>string</td><td>null</td></tr><tr><td>order_count</td><td>bigint</td><td>null</td></tr><tr><td>total_sales</td><td>double</td><td>null</td></tr><tr><td>avg_order_value</td><td>double</td><td>null</td></tr><tr><td># Partition Information</td><td></td><td></td></tr><tr><td># col_name</td><td>data_type</td><td>comment</td></tr><tr><td>month_key</td><td>string</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ## Customers purchase frequency

# %%
# %sql
SELECT 
  order_count,
  COUNT(*) AS customer_count
FROM (
  SELECT 
    CustomerID,
    COUNT(DISTINCT orderID) AS order_count
  FROM silver.sales_2k
  GROUP BY CustomerID
) AS customer_orders
GROUP BY order_count
ORDER BY order_count
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_count</th><th>customer_count</th></tr></thead><tbody><tr><td>1</td><td>2200</td></tr><tr><td>2</td><td>2366</td></tr><tr><td>3</td><td>1754</td></tr><tr><td>4</td><td>983</td></tr><tr><td>5</td><td>450</td></tr><tr><td>6</td><td>203</td></tr><tr><td>7</td><td>46</td></tr><tr><td>8</td><td>7</td></tr><tr><td>9</td><td>2</td></tr><tr><td>10</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
SELECT 
  CASE 
    WHEN order_count BETWEEN 1 AND 3 THEN '1–3 orders'
    WHEN order_count BETWEEN 4 AND 6 THEN '4–6 orders'
    ELSE '7+ orders'
  END AS order_range,
  COUNT(*) AS customer_count
FROM (
  SELECT 
    customerID,
    COUNT(DISTINCT orderID) AS order_count
  FROM silver.sales_2k
  GROUP BY customerID
) AS customer_orders
GROUP BY order_range
ORDER BY 
  CASE 
    WHEN order_range = '1–3 orders' THEN 1
    WHEN order_range = '4–6 orders' THEN 2
    ELSE 3
  END
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_range</th><th>customer_count</th></tr></thead><tbody><tr><td>1–3 orders</td><td>6320</td></tr><tr><td>4–6 orders</td><td>1636</td></tr><tr><td>7+ orders</td><td>56</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ## Top customer spendings for early access discounts or products

# %%
# %sql
SELECT 
  customerID,
  COUNT(DISTINCT orderID) AS total_orders,
  SUM(TotalAmount) AS total_spent
FROM silver.sales_2k
GROUP BY customerID
ORDER BY total_spent DESC
LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customerID</th><th>total_orders</th><th>total_spent</th></tr></thead><tbody><tr><td>C5150</td><td>8</td><td>38617.100000000006</td></tr><tr><td>C6955</td><td>6</td><td>37114.11</td></tr><tr><td>C9957</td><td>6</td><td>35930.35</td></tr><tr><td>C2068</td><td>9</td><td>34395.88</td></tr><tr><td>C6393</td><td>5</td><td>33379.03</td></tr><tr><td>C2357</td><td>9</td><td>32719.019999999997</td></tr><tr><td>C5126</td><td>8</td><td>32685.320000000003</td></tr><tr><td>C4945</td><td>6</td><td>31711.170000000002</td></tr><tr><td>C1759</td><td>6</td><td>30758.72</td></tr><tr><td>C2054</td><td>7</td><td>30756.950000000004</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ## Average Order Value

# %%
# %sql
SELECT 
  DATE_FORMAT(OrderDate, 'yyyy-MM') AS month,
  SUM(TotalAmount) / COUNT(DISTINCT OrderID) AS avg_order_value
FROM silver.sales_2k
GROUP BY DATE_FORMAT(OrderDate, 'yyyy-MM')
ORDER BY month
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>avg_order_value</th></tr></thead><tbody><tr><td>2024-06</td><td>2844.2020936902454</td></tr><tr><td>2024-07</td><td>2819.027974910397</td></tr><tr><td>2024-08</td><td>2777.8621213942347</td></tr><tr><td>2024-09</td><td>2855.2458780487777</td></tr><tr><td>2024-10</td><td>2765.603415898617</td></tr><tr><td>2024-11</td><td>2792.231661631417</td></tr><tr><td>2024-12</td><td>2809.535342150663</td></tr><tr><td>2025-01</td><td>2787.423052184468</td></tr><tr><td>2025-02</td><td>2707.225029051003</td></tr><tr><td>2025-03</td><td>2805.8490171699236</td></tr><tr><td>2025-04</td><td>2870.1605514705857</td></tr><tr><td>2025-05</td><td>2824.1642404692047</td></tr><tr><td>2025-06</td><td>2668.047945425361</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
SELECT 
  DATE_FORMAT(OrderDate, 'yyyy-MM') AS month,
  ROUND(SUM(TotalAmount) / COUNT(DISTINCT OrderID), 2) AS latest_aov
FROM silver.sales_2k
GROUP BY month
ORDER BY month DESC
LIMIT 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>latest_aov</th></tr></thead><tbody><tr><td>2025-06</td><td>2668.05</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ## Quantity ~ TotalSales ~ Day of the week

# %%
# %sql
SELECT 
  date_format(OrderDate, 'EEEE') AS day_of_week,  
  COUNT(OrderID) AS order_count,
  SUM(Quantity) AS total_quantity,
  SUM(TotalAmount) AS total_sales
FROM silver.sales_2k
GROUP BY 
  date_format(OrderDate, 'EEEE')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
>West</td><td>1084508.5100000005</td></tr><tr><td>Monitor</td><td>North</td><td>994989.3200000003</td></tr><tr><td>Smartphone</td><td>West</td><td>784319.5999999997</td></tr><tr><td>Keyboard</td><td>North</td><td>1087516.3000000007</td></tr><tr><td>Webcam</td><td>North</td><td>953570.44</td></tr><tr><td>Bookshelf</td><td>East</td><td>1228796.9</td></tr><tr><td>Webcam</td><td>South</td><td>931342.3499999996</td></tr><tr><td>Mechanical Keyboard</td><td>South</td><td>400.0</td></tr><tr><td>Office Chair</td><td>East</td><td>1170304.0099999995</td></tr><tr><td>Laptop Stand</td><td>East</td><td>75.0</td></tr><tr><td>Headphones</td><td>West</td><td>1373867.3499999985</td></tr><tr><td>USB Drive</td><td>North</td><td>1081021.7100000002</td></tr><tr><td>Unknown</td><td>West</td><td>124189.26</td></tr><tr><td>Printer</td><td>West</td><td>964815.8800000005</td></tr><tr><td>Unknown</td><td>East</td><td>187483.39000000004</td></tr><tr><td>Monitor</td><td>West</td><td>960058.0599999995</td></tr><tr><td>Laptop</td><td>East</td><td>960650.6200000007</td></tr><tr><td>Desk</td><td>North</td><td>1079646.3899999997</td></tr><tr><td>Mouse</td><td>East</td><td>1086905.2899999998</td></tr><tr><td>Keyboard</td><td>West</td><td>1091352.3399999999</td></tr><tr><td>Keyboard</td><td>East</td><td>1253475.4699999993</td></tr><tr><td>Smartphone</td><td>East</td><td>916058.1</td></tr><tr><td>Headphones</td><td>South</td><td>1179270.0600000003</td></tr><tr><td>Headphones< ...
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ## Discount Impact Analysis
# ### the discount is applied to the products at the same rate so we will check if the lowered price items sell more
# ### depending on this data there is very less impact of dicounting

# %%
# %sql
SELECT 
CORR(unitprice, quantity) AS price_quantity_corr,
  FLOOR(unitprice * 2) / 2 AS price_bucket, 
  SUM(quantity) AS total_quantity_sold
FROM silver.sales_2k
WHERE quantity > 0
GROUP BY price_bucket
ORDER BY price_bucket

limit 50
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>price_quantity_corr</th><th>price_bucket</th><th>total_quantity_sold</th></tr></thead><tbody><tr><td>0.12807198644161882</td><td>20.0</td><td>59</td></tr><tr><td>0.4798709064331247</td><td>20.5</td><td>40</td></tr><tr><td>0.22714226864763468</td><td>21.0</td><td>39</td></tr><tr><td>-0.24068314578910138</td><td>21.5</td><td>56</td></tr><tr><td>0.5254910318244435</td><td>22.0</td><td>67</td></tr><tr><td>-0.047403686760132485</td><td>22.5</td><td>59</td></tr><tr><td>-0.23471237222357413</td><td>23.0</td><td>92</td></tr><tr><td>-0.5710235890668331</td><td>23.5</td><td>40</td></tr><tr><td>0.026855071552894797</td><td>24.0</td><td>61</td></tr><tr><td>0.3295104686782301</td><td>24.5</td><td>67</td></tr><tr><td>-0.021145859725971577</td><td>25.0</td><td>79</td></tr><tr><td>0.016789773531778282</td><td>25.5</td><td>78</td></tr><tr><td>0.3711796893262979</td><td>26.0</td><td>40</td></tr><tr><td>-0.4792912726467037</td><td>26.5</td><td>57</td></tr><tr><td>-0.16147514599214868</td><td>27.0</td><td>53</td></tr><tr><td>0.49094136771683605</td><td>27.5</td><td>44</td></tr><tr><td>0.10037041426827145</td><td>28.0</td><td>70</td></tr><tr><td>-0.8863397863266633</td><td>28.5</td><td>33</td></tr><tr><td>0.02028135894327601</td><td>29.0</td><td>62</td></tr><tr><td>0.3526150543468893</td><td>29.5</td><td>31</td></tr><tr><td>-0.019547771808352148</td><td>30.0</td><td>66</td></tr><tr><td>0.4373725806357179</td><td>30.5</td><td>68</td></tr><tr><td>0.5025229775754718</td><td>31.0</td><td>57</td></tr><tr><td>-1.0000000000000118</td><td>31.5</td><td>15</td></tr><tr><td>0.836507948003962</td><td>32.0</td><td>21</td></tr><tr><td>0.3013146202501115</td><td>32.5</td><td>65</td></tr><tr><td>0.296059565886847</td><td>33.0</td><td>101</td></tr><tr><td>0.2967717769597724</td><td>33.5</td><td>85</td></tr><tr><td>-0.5189190125114341</td><td>34.0</td><td>63</td></tr><tr><td>0.18926010459291034</td><td>34.5</td><td>99</td></tr><tr><td>-0.0158742750453961</td><td>35.0</td><td>36</td></tr><tr><td>0.4564086886016435</td><td>35.5</td><td>49</td></tr><tr><td>-0.442522730814667</td><td>36.0</td><td>75</td></tr><tr><td>-0.6606652676327862</td><td>36.5</td><td>43</td></tr><tr><td>0.32403016590944117</td><td>37.0</td><td>49</td></tr><tr><td>0.5198551283406825</td><td>37.5</td><td>53</td></tr><tr><td>-0.15170103526252232</td><td>38.0</td><td>28</td></tr><tr><td>-0.30666757776981773</td><td>38.5</td><td>66</td></tr><tr><td>0.8351522876715748</td><td>39.0</td><td>48</td></tr><tr><td>0.06877634686276347</td><td>39.5</td><td>79</td></tr><tr><td>-0.08960823371115342</td><td>40.0</td><td>67</td></tr><tr><td>0.9655422276454824</td><td>40.5</td><td>30</td></tr><tr><td>0.2772706020449706</td><td>41.0</td><td>64</td></tr><tr><td>-0.4562563700702029</td><td>41.5</td><td>32</td></tr><tr><td>0.09811851359427225</td><td>42.0</td><td>48</td></tr><tr><td>0.15049503422127064</td><td>42.5</td><td>59</td></tr><tr><td>-0.12848853712349753</td><td>43.0</td><td>78</td></tr><tr><td>0.27517177688199973</td><td>43.5</td><td>52</td></tr><tr><td>0.06378848375995808</td><td>44.0</td><td>92</td></tr><tr><td>-0.7945217050222858</td><td>44.5</td><td>59</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
WITH first_orders AS (
  SELECT customerID, MIN(OrderDate) AS first_order_date
  FROM silver.sales_2k
  GROUP BY customerID
),
tagged_orders AS (
  SELECT 
    s.customerID,
    s.orderID,
    s.OrderDate,
    s.TotalAmount,
    CASE 
      WHEN s.OrderDate = f.first_order_date THEN 'New'
      ELSE 'Returning'
    END AS customer_type
  FROM silver.sales_2k s
  JOIN first_orders f ON s.customerID = f.customerID
)

SELECT 
  customer_type,
  COUNT(DISTINCT customerID) AS customer_count,
  COUNT(orderID) AS total_orders,
  SUM(TotalAmount) AS total_revenue
FROM tagged_orders
GROUP BY customer_type
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_type</th><th>customer_count</th><th>total_orders</th><th>total_revenue</th></tr></thead><tbody><tr><td>Returning</td><td>5810</td><td>11972</td><td>3.370250527999996E7</td></tr><tr><td>New</td><td>8012</td><td>8028</td><td>2.2292301309999976E7</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
